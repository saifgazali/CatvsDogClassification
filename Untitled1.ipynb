# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

data_dir = 'dataset1/pet_images'
categories = ['dogs','cats']

for category in categories:
    path = os.path.join(data_dir,category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE) #Converting them to graysccale
        break
    break

# %%
print(img_array.shape)
# Out:
# (499, 327)

# %%
print(img_array)
# Out:
# [[227 156 121 ... 109 104 103]
#  [237 158 113 ...  91  87  86]
#  [233 152 107 ...  61  59  60]
#  ...
#  [255 253 249 ... 238 237 237]
#  [255 254 251 ... 244 243 243]
#  [255 255 253 ... 249 247 248]]

# %%
img_array = img_array.astype(float)

# %%
plt.imshow(img_array,cmap='gray')

# %%
IMG_SIZE = 50

new_array = cv2.resize(img_array, (IMG_SIZE,IMG_SIZE))
plt.imshow(new_array,cmap='gray')

# %%
training_data = []

def create_training_data():
    for category in categories:
        path = os.path.join(data_dir,category)
        class_num = categories.index(category)
        for img in os.listdir(path):
            img_array = cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE) #Converting them to graysccale
            img_array = img_array.astype(float)
            new_array = cv2.resize(img_array, (IMG_SIZE,IMG_SIZE))
            training_data.append([new_array,class_num])

# %%
create_training_data()

# %%
print(len(training_data))
# Out:
# 8000

# %%
#Shuffling the data as our training data as all dogs first and then all cats

import random

random.shuffle(training_data)

# %%
plt.imshow(training_data[0][0])

# %%
X = []
Y = []

# %%
for features,label in training_data:
    X.append(features)
    Y.append(label)
X = np.array(X).reshape(-1,IMG_SIZE,IMG_SIZE,1)

# %%
import pickle 

pickle_out = open('x.pickle','wb')
pickle.dump(X,pickle_out)
pickle_out.close()

# %%
pickle_out = open('y.pickle','wb')
pickle.dump(Y,pickle_out)
pickle_out.close()

# %%
# checking
pickle_in = open('x.pickle','rb')
temp = pickle.load(pickle_in)

# %%
plt.imshow(temp[0])

# %%
print(categories[Y[0]])
# Out:
# dogs
